# %% [markdown]
# # [Youtube Source Video](https://www.youtube.com/watch?v=dccf_sJF0Gg)

# %% [markdown]
# # Dataset Set-Up

# %%
# !pip install ultralytics
# !pip install roboflow


from roboflow import Roboflow
rf = Roboflow(api_key="3qduNDzsBSXEa73QGWfB")
project = rf.workspace("college-vlzv7").project("student-monitoring-system")
version = project.version(5)
dataset = version.download("yolov8")
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.3/41.3 kB 1.4 MB/s eta 0:00:00
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# ...
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# ...

# %% [markdown]
# data.yaml
#
# ```
# names:
# - High Attention
# - Low Attention
# nc: 2
# roboflow:
#   license: CC BY 4.0
#   project: student-monitoring-system
#   url: https://universe.roboflow.com/college-vlzv7/student-monitoring-system/dataset/5
#   version: 5
#   workspace: college-vlzv7
# test: /content/Student-Monitoring-System-5/test
# train: /content/Student-Monitoring-System-5/train
# val: /content/Student-Monitoring-System-5/valid/images
#
# ```

# %% [markdown]
# # YOLOv8

# %%
# from ultralytics import YOLO

# # # Load a model YOLOv9
# model = YOLO("yolov8n.pt")  # load a pretrained model (recommended for training)

# %%
# # Train the model with YOLOv8
# results = model.train(data="/content/Student-Monitoring-System-5/data.yaml", epochs=100, imgsz=640, batch=8)

# %% [markdown]
# # YOLOv9

# %%
from ultralytics import YOLO

# Load a model YOLOv9
model = YOLO("yolov9c.pt")  # load a pretrained model (recommended for training)
# Out:
# ...
# 100%|██████████| 49.4M/49.4M [00:00<00:00, 91.8MB/s]

# %%
# Train the model with YOLOv9
results = model.train(data="/content/Student-Monitoring-System-5/data.yaml", epochs=100, imgsz=640, batch=8)
# Out:
# Ultralytics YOLOv8.2.79 🚀 Python-3.10.12 torch-2.3.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %% [markdown]
# # Run Model

# %%
from ultralytics import YOLO
import cv2
from google.colab.patches import cv2_imshow # Import the correct function for displaying images in Colab

# Load the PyTorch model
model = YOLO('/content/runs/detect/train4/weights/best.pt')

# Load the image
image = cv2.imread('/content/img3.jpg')

# Run prediction on the image
results = model.predict(source=image)

# Plot the annotated image
annotated_image = results[0].plot()

# Display the annotated image using cv2_imshow
cv2_imshow(annotated_image) # Use cv2_imshow instead of cv2.imshow
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# 0: 320x640 12 High Attentions, 5 Low Attentions, 109.9ms
# Speed: 2.3ms preprocess, 109.9ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
# <PIL.Image.Image image mode=RGB size=1600x800>

# %% [markdown]
# # Save/Download Model

# %%
from google.colab import files

# Path to your model weights
model_path = '/content/runs/detect/train4/weights/best.pt'

# Download the model
files.download(model_path)
