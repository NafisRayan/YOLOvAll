# %% [markdown]
# # [Youtube Source Video](https://www.youtube.com/watch?v=dccf_sJF0Gg)

# %% [markdown]
# # Dataset Set-Up

# %%
# !pip install ultralytics
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="3qduNDzsBSXEa73QGWfB")
project = rf.workspace("hailhydra").project("car-damage-coco-dataset-lrmpk")
version = project.version(2)
dataset = version.download("yolov9")
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.9/41.9 kB 1.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 871.7/871.7 kB 18.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.9/79.9 kB 3.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 5.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 4.7 MB/s eta 0:00:00
# ...
#   Attempting uninstall: idna
#     Found existing installation: idna 3.8
#     Uninstalling idna-3.8:
#       Successfully uninstalled idna-3.8
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to car-damage-coco-dataset-2 in yolov9:: 100%|██████████| 3412/3412 [00:00<00:00, 6745.81it/s]

# %% [markdown]
# data.yaml
#
# ```
# names:
# - Car-Damage
# nc: 1
# roboflow:
#   license: Public Domain
#   project: car-damage-coco-dataset-lrmpk
#   url: https://universe.roboflow.com/hailhydra/car-damage-coco-dataset-lrmpk/dataset/2
#   version: 2
#   workspace: hailhydra
# test: /content/test/images
# train: /content/car-damage-coco-dataset-2/train/images
# val: /content/car-damage-coco-dataset-2/valid/images
#
# ```

# %% [markdown]
# # YOLOv8

# %%
# from ultralytics import YOLO

# # # Load a model YOLOv9
# model = YOLO("yolov8n.pt")  # load a pretrained model (recommended for training)

# %%
# # Train the model with YOLOv8
# results = model.train(data="/content/Sign-1/data.yaml", epochs=100, imgsz=640, batch=8)

# %% [markdown]
# # YOLOv9

# %%
from ultralytics import YOLO

# Load a model YOLOv9
model = YOLO("yolov9c.pt")  # load a pretrained model (recommended for training)
# Out:
# ...
# 100%|██████████| 49.4M/49.4M [00:00<00:00, 129MB/s]

# %%
# Train the model with YOLOv9
results = model.train(data="/content/car-damage-coco-dataset-2/data.yaml", epochs=100, imgsz=640, batch=8)
# Out:
# Ultralytics YOLOv8.2.89 🚀 Python-3.10.12 torch-2.4.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %% [markdown]
# # Run Model

# %%
from ultralytics import YOLO
import cv2
from google.colab.patches import cv2_imshow # Import the correct function for displaying images in Colab

# Load the PyTorch model
model = YOLO('/content/runs/detect/train2/weights/best.pt')

# Load the image
image = cv2.imread('/content/img.jpg')

# Run prediction on the image
results = model.predict(source=image)

# Plot the annotated image
annotated_image = results[0].plot()

# Display the annotated image using cv2_imshow
cv2_imshow(annotated_image) # Use cv2_imshow instead of cv2.imshow
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# 0: 480x640 1 Car-Damage, 108.8ms
# Speed: 4.8ms preprocess, 108.8ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
# <PIL.Image.Image image mode=RGB size=1200x900>

# %% [markdown]
# # Save/Download Model

# %%
from google.colab import files

# Path to your model weights
model_path = '/content/runs/detect/train2/weights/best.pt'

# Download the model
files.download(model_path)
